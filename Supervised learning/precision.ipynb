# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('collegedata.csv')
df.head()
# Out:
#        CGPA      Score  Placed
# 0  7.498160  52.584086       0
# 1  9.802857  76.567732       1
# 2  8.927976  77.031756       1
# 3  8.394634  81.871495       1
# 4  6.624075  86.304567       1

# %%
x = df.iloc[:,:-1]
y= df['Placed']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=35)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
from sklearn.metrics import confusion_matrix

# %%
cef = confusion_matrix(y_test,lr.predict(x_test))

# %%
sns.heatmap(cef,annot=True)
plt.show()
