# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('customer_data.csv')
df.head()
# Out:
#    Age  Income  Gender  Marital Status  Purchased
# 0   56   54674       1               0          0
# 1   69   55854       0               0          1
# 2   46   66271       1               0          1
# 3   32   93688       0               0          0
# 4   60   58518       1               0          1

# %%
x = df.iloc[:,:-1]
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#           Age    Income    Gender  Marital Status
# 0    0.812959 -0.504589  0.976281       -1.040833
# 1    1.680578 -0.463393 -1.024295       -1.040833
# 2    0.145560 -0.099711  0.976281       -1.040833
# 3   -0.788799  0.857481 -1.024295       -1.040833
# 4    1.079919 -0.370386  0.976281       -1.040833
# ..        ...       ...       ...             ...
# 995  1.079919  1.719990 -1.024295       -1.040833
# 996  1.346879  0.060537  0.976281       -1.040833
# 997  1.213399  0.934602 -1.024295        0.960769
# 998 -0.588580  1.144355  0.976281       -1.040833
# 999  0.746219  0.679044 -1.024295        0.960769
#
# [1000 rows x 4 columns]

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=12)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_test,y_test)*100
# Out:
# 50.8

# %%
dt.predict([[56,54674,1,0]])
# Out:
# C:\Users\hrida\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dt)

plt.show()
