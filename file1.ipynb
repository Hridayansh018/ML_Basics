# %% [markdown]
# # **======================================**

# %% [markdown]
# # **Machine Learning Basics**

# %% [markdown]
# # **======================================**

# %% [markdown]
# ### ***EDA BASIC WITH PANDAS, NUMPY, SEABORN, MATPLOTLIB DONE***
# ### ***NOW ITS TIME FOR SCIKIT LEARN LIBRARY***

# %% [markdown]
# # **======================================**

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
dts = pd.read_csv('fifa_eda.csv')
dts.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
dts.info()
dts.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
floatC = dts.select_dtypes(include='float64').columns
#dtns = dts.select_dtypes(include='number' and 'float64')
#dtns.info()

# %%
intC = dts.select_dtypes(include='int64').columns

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dts[floatC])

# %%
#newdts = pd.DataFrame(ar,columns=dts.select_dtypes(include='float64').columns)
newdts = pd.DataFrame(ar,columns=floatC)

# %%
for col in intC:
    newdts[col] = dts[col]

# %%
non_intC = dts.select_dtypes(exclude=['int64','float64']).columns
for col in non_intC:
    newdts[col] = dts[col]

# %%
newdts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Value                     18207 non-null  float64
#  1   Wage                      18207 non-null  float64
#  2   International Reputation  18207 non-null  float64
#  3   Skill Moves               18207 non-null  float64
#  4   Height                    18207 non-null  float64
#  5   Weight                    18207 non-null  float64
#  6   Release Clause            18207 non-null  float64
#  7   ID                        18207 non-null  int64
#  8   Age                       18207 non-null  int64
#  9   Overall                   18207 non-null  int64
#  10  Potential                 18207 non-null  int64
#  11  Joined                    18207 non-null  int64
#  12  Name                      18207 non-null  object
# ...

# %%
newdts.isnull().sum()
# Out:
# Value                         0
# Wage                          0
# International Reputation      0
# Skill Moves                   0
# Height                        0
# Weight                        0
# Release Clause                0
# ID                            0
# Age                           0
# Overall                       0
# Potential                     0
# Joined                        0
# Name                          0
# Nationality                   0
# Club                        241
# Preferred Foot                0
# Position                      0
# Contract Valid Until        289
# dtype: int64

# %%
newdts['Club']=newdts['Club'].bfill()
newdts['Contract Valid Until']=newdts['Contract Valid Until'].bfill()
newdts.isnull().sum()
# Out:
# Value                       0
# Wage                        0
# International Reputation    0
# Skill Moves                 0
# Height                      0
# Weight                      0
# Release Clause              0
# ID                          0
# Age                         0
# Overall                     0
# Potential                   0
# Joined                      0
# Name                        0
# Nationality                 0
# Club                        0
# Preferred Foot              0
# Position                    0
# Contract Valid Until        0
# dtype: int64

# %% [markdown]
# ### **ONEHOTENCODING**

# %%
dnx = pd.read_csv("loan-test.csv")
dnx.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
dnx['Gender']=dnx['Gender'].bfill()
dnx['Dependents']=dnx['Dependents'].bfill()
dnx['Self_Employed']=dnx['Self_Employed'].ffill()
dnx['LoanAmount']=dnx['LoanAmount'].mean()
dnx['Loan_Amount_Term']=dnx['Loan_Amount_Term'].mean()
dnx['Credit_History']=dnx['Credit_History'].ffill()
dnx.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0  136.132597        342.537396
# 1             3076               1500  136.132597        342.537396
# 2             5000               1800  136.132597        342.537396
# 3             2340               2546  136.132597        342.537396
# 4             3276                  0  136.132597        342.537396
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
dnx.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
en_data = dnx[['Gender','Married']]
pd.get_dummies(en_data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender_Female  367 non-null    bool
#  1   Gender_Male    367 non-null    bool
#  2   Married_No     367 non-null    bool
#  3   Married_Yes    367 non-null    bool
# dtypes: bool(4)
# memory usage: 1.6 KB

# %%
en_data
# Out:
#     Gender Married
# 0     Male     Yes
# 1     Male     Yes
# 2     Male     Yes
# 3     Male     Yes
# 4     Male      No
# ..     ...     ...
# 362   Male     Yes
# 363   Male     Yes
# 364   Male      No
# 365   Male     Yes
# 366   Male      No
#
# [367 rows x 2 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()
ohe.fit_transform(en_data)
# Out:
# <367x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 734 stored elements in Compressed Sparse Row format>

# %%
arx = ohe.fit_transform(en_data).toarray()

# %%
pd.DataFrame(arx,columns=["Gender_Female","Gender_Male","Married_No","Married_Yes"])
# Out:
#      Gender_Female  Gender_Male  Married_No  Married_Yes
# 0              0.0          1.0         0.0          1.0
# 1              0.0          1.0         0.0          1.0
# 2              0.0          1.0         0.0          1.0
# 3              0.0          1.0         0.0          1.0
# 4              0.0          1.0         1.0          0.0
# ..             ...          ...         ...          ...
# 362            0.0          1.0         0.0          1.0
# 363            0.0          1.0         0.0          1.0
# 364            0.0          1.0         1.0          0.0
# 365            0.0          1.0         0.0          1.0
# 366            0.0          1.0         1.0          0.0
#
# [367 rows x 4 columns]

# %% [markdown]
# ### **LABELENCODING**

# %%
df = pd.DataFrame({"name":["asus","cat","dog","black","cow"]})
df
# Out:
#     name
# 0   asus
# 1    cat
# 2    dog
# 3  black
# 4    cow

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit_transform(df["name"])
# Out:
# array([0, 2, 4, 1, 3])

# %%
df['en_name'] = le.fit_transform(df["name"])
df
# Out:
#     name  en_name
# 0   asus        0
# 1    cat        2
# 2    dog        4
# 3  black        1
# 4    cow        3

# %%
dataset = pd.read_csv("loan-test.csv")
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
la = LabelEncoder()
la.fit(dataset['Property_Area'])
# Out:
# LabelEncoder()

# %%
la.transform(dataset['Property_Area'])
# Out:
# array([2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2, 1, 2, 2,
#        2, 2, 2, 0, 2, 2, 1, 2, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 1,
#        2, 2, 2, 1, 2, 1, 2, 1, 1, 2, 2, 2, 0, 1, 1, 1, 1, 2, 1, 0, 2, 1,
#        1, 1, 1, 0, 1, 1, 2, 0, 1, 2, 2, 0, 1, 2, 2, 2, 0, 0, 1, 0, 2, 1,
#        1, 0, 0, 0, 1, 1, 1, 1, 2, 1, 2, 1, 0, 1, 2, 0, 1, 1, 2, 0, 1, 2,
#        1, 1, 2, 1, 0, 1, 1, 0, 2, 0, 2, 0, 2, 0, 2, 1, 2, 2, 2, 1, 2, 0,
#        0, 2, 2, 2, 0, 0, 1, 1, 0, 0, 2, 1, 0, 2, 1, 0, 1, 2, 2, 2, 0, 2,
#        0, 1, 2, 0, 1, 0, 0, 1, 2, 0, 0, 1, 2, 2, 1, 0, 0, 0, 0, 2, 0, 0,
#        2, 0, 0, 2, 1, 1, 2, 0, 2, 1, 1, 1, 0, 0, 0, 2, 0, 0, 1, 2, 1, 0,
#        2, 0, 0, 2, 2, 1, 1, 1, 1, 1, 2, 0, 2, 0, 1, 0, 0, 2, 1, 0, 0, 2,
#        2, 0, 2, 0, 1, 2, 2, 0, 0, 2, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 2, 1,
#        1, 0, 1, 1, 2, 2, 1, 0, 2, 1, 1, 2, 2, 0, 0, 2, 0, 0, 1, 1, 0, 0,
#        0, 1, 2, 0, 0, 0, 2, 0, 1, 1, 1, 1, 2, 1, 1, 1, 1, 0, 2, 0, 2, 2,
# ...

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %% [markdown]
# ### **RODINAL ENCODING**

# %% [markdown]
# - **With Sklearn**

# %%
df = pd.DataFrame({"size":['s','m','l','xl','s','m','l','s','s','l','xl','m']})
ordata = [['s','m','l','xl']]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=ordata)
oe.fit(df[['size']])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
oe.transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [0.],
#        [2.],
#        [3.],
#        [1.]])

# %%
df['size_en'] = oe.transform(df[['size']])
df
# Out:
#    size  size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     s      0.0
# 9     l      2.0
# 10   xl      3.0
# 11    m      1.0

# %% [markdown]
# - **with "map()" function**

# %%
ordata1 = { "s":1, "m":2, "l":3, "xl":4 }
df['size'].map(ordata1)
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     1
# 5     2
# 6     3
# 7     1
# 8     1
# 9     3
# 10    4
# 11    2
# Name: size, dtype: int64

# %%
df['size_en_map'] = df['size'].map(ordata1)
df
# Out:
#    size  size_en  size_en_map
# 0     s      0.0            1
# 1     m      1.0            2
# 2     l      2.0            3
# 3    xl      3.0            4
# 4     s      0.0            1
# 5     m      1.0            2
# 6     l      2.0            3
# 7     s      0.0            1
# 8     s      0.0            1
# 9     l      2.0            3
# 10   xl      3.0            4
# 11    m      1.0            2

# %%
dataset = pd.read_csv("loan-test.csv")
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %%
en_data_ord = [['Rural','Semiurban','Urban']]
oen = OrdinalEncoder(categories=en_data_ord)

# %%
oen.fit_transform(dataset[['Property_Area']])
dataset['Property_Area']=oen.fit_transform(dataset[['Property_Area']])
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History  Property_Area
# 0             1.0            2.0
# 1             1.0            2.0
# 2             1.0            2.0
# ...

# %% [markdown]
# ### **OUTLIER**
# - **Data that is out of range**

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='CoapplicantIncome',data=dataset)
plt.show()

# %%
dataset.shape
# Out:
# (367, 12)

# %%
q1 = dataset['CoapplicantIncome'].quantile(0.25)
q3 = dataset['CoapplicantIncome'].quantile(0.75)

# %%
IQR = q3-q1

# %% [markdown]
# - **Finding The Maximun And Minimum range of data**

# %%
min_range = q1-(1.5*IQR)
max_range = q3+(1.5*IQR)
min_range , max_range
# Out:
# (-3645.75, 6076.25)

# %% [markdown]
# - **Removing Outliers by setting the data less than maximum range(Because 'min_range' is Negative**)

# %%
new_dataset = dataset[dataset['CoapplicantIncome']<=max_range]
new_dataset
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
new_dataset.shape
# Out:
# (359, 12)

# %%
sns.boxplot(data=new_dataset,x='CoapplicantIncome')
plt.show()

# %%
dataset = pd.read_csv('loan-train.csv')
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
dataset.describe(), dataset.shape
# Out:
# (       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
#  count       614.000000         614.000000  592.000000         600.00000
#  mean       5403.459283        1621.245798  146.412162         342.00000
#  std        6109.041673        2926.248369   85.587325          65.12041
#  min         150.000000           0.000000    9.000000          12.00000
#  25%        2877.500000           0.000000  100.000000         360.00000
#  50%        3812.500000        1188.500000  128.000000         360.00000
#  75%        5795.000000        2297.250000  168.000000         360.00000
#  max       81000.000000       41667.000000  700.000000         480.00000
#
#         Credit_History
#  count      564.000000
#  mean         0.842199
#  std          0.364878
#  min          0.000000
#  25%          1.000000
#  50%          1.000000
#  75%          1.000000
#  max          1.000000  ,
#  (614, 13))

# %%
sns.boxplot(data=dataset,x="CoapplicantIncome")
plt.show()

# %%
sns.distplot(dataset['CoapplicantIncome'])
plt.show()
# Out:
# C:\Users\hrida\AppData\Local\Temp\ipykernel_17136\3783729653.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['CoapplicantIncome'])

# %%
min_range = dataset['CoapplicantIncome'].mean() - dataset['CoapplicantIncome'].std()
min_range = dataset['CoapplicantIncome'].mean() + dataset['CoapplicantIncome'].std()
min_range, max_range
# Out:
# (4547.49416725129, 6076.25)

# %%
new_dataset = dataset[dataset['CoapplicantIncome']<=max_range]
new_dataset.shape
# Out:
# (596, 13)

# %%
sns.boxplot(new_dataset,x='CoapplicantIncome')
plt.show()

# %%
z_score = (dataset['CoapplicantIncome'] - dataset['CoapplicantIncome'].mean())/dataset['CoapplicantIncome'].std()
z_score
# Out:
# 0     -0.554036
# 1     -0.038700
# 2     -0.554036
# 3      0.251774
# 4     -0.554036
#          ...
# 609   -0.554036
# 610   -0.554036
# 611   -0.472019
# 612   -0.554036
# 613   -0.554036
# Name: CoapplicantIncome, Length: 614, dtype: float64

# %%
dataset['z_score'] = z_score
dataset[dataset['z_score']<3]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
